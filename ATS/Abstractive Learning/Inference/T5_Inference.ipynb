# %%
import os
import json
import time
import torch
import random 
import numpy as np
import pandas as pd
from statistics import mean
from matplotlib import pyplot as plt

import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from transformers import T5Config, AutoTokenizer, T5ForConditionalGeneration, AdamW, get_cosine_with_hard_restarts_schedule_with_warmup
from tqdm import tqdm, trange

import os
os.environ['TOKENIZERS_PARALLELISM'] = 'false'

# %%
# read the file for which we need the predictions.
df = pd.read_excel('../DATA/combined_test_bottlesum_results.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   article       103 non-null    object
#  1   Summary       103 non-null    object
#  2   highlights    103 non-null    object
#  3   noisy         103 non-null    object
#  4   Pronoun_swap  103 non-null    object
#  5   deleted       103 non-null    object
# dtypes: object(6)
# memory usage: 5.0+ KB

# %%
df.head(2)
# Out:
#                                              article  \
# 0  (CNN)James Best, best known for his portrayal ...
# 1  (CNN)The attorney for a suburban New York card...
#
#                                              Summary  \
# 0   (cnn) james best, best known for his portraya...
# 1   (cnn) the attorney for a suburban new york ca...
#
#                                           highlights  \
# 0  James Best, who played the sheriff on "The Duk...
# 1  A lawyer for Dr. Anthony Moschetto says the ch...
#
#                                                noisy  \
# 0  james best, who played the sheriff on "the duk...
# 1  a lawyer for dr. anthony moschetto did not did...
#
#                                         Pronoun_swap  \
# 0  james best, who played an sheriff on "the duke...
# 1  the lawyer for dr. anthony moschetto says an c...
#
#                                              deleted
# 0  james best, played the sheriff sheriff on duke...
# 1  lawyer for anthony says the charges are basele...

# %%
# seeding everything.
def seed_everything(seed):
    """
    Seeds basic parameters for reproductibility of results
    
    Arguments:
    
        seed {int} -- Number of the seed
    """
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed = 2021
seed_everything(seed)

# %%
# load the tokenizer and finetuned model.
tokenizer = AutoTokenizer.from_pretrained("t5-large")
model = T5ForConditionalGeneration.from_pretrained("../Training/T5_Model_BottleSum_1-340/")
# Out:
# /opt/conda/lib/python3.7/site-packages/transformers/models/t5/tokenization_t5_fast.py:166: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-large automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,

# %%
# moving the model to GPU.
_ = model.to('cuda:0')

# %%
"""
def prompt(n):
    #print(df.iloc[n]['highlights'])
    return 'summarize: %s' % (df.iloc[n]['distilbart-cnn-12-6'])
"""

# function to return the prompt at nth loaction in a predefined format for summarization.
def prompt(n):
    return 'summarize: %s' % (df.iloc[n]['Summary'])

# %%
# creating an empty list for saving the Predictions from model.
Pred = []

# looping thought all the examples in the dataset.
for i in trange(len(df)):

    # accessing the prompt using prompt function.
    text = prompt(i)
    
    # tokenising the text using tokenizer. And moving to GPU.
    inputs = tokenizer(text, return_tensors='pt').to('cuda:0')
    
    # generating the summary using generate method in model.
    output = model.generate(**inputs, max_length=200)
    
    #print("\n\n", tokenizer.decode(output[0], skip_special_tokens=True))
    Pred.append(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
#   2%|█▉                                                                                                  | 2/103 [00:03<02:44,  1.63s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (528 > 512). Running this sequence through the model will result in indexing errors
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 103/103 [03:11<00:00,  1.86s/it]

# %%
# checking the lengths of df and Pred.
len(df), len(Pred)
# Out:
# (103, 103)

# %%
df['Predictions'] = Pred

# %%
df
# Out:
#                                                article  \
# 0    (CNN)James Best, best known for his portrayal ...
# 1    (CNN)The attorney for a suburban New York card...
# 2    (CNN)President Barack Obama took part in a rou...
# 3    Moscow (CNN)A Russian TV channel aired Hillary...
# 4    (CNN)Marco Rubio is all in.  The Republican se...
# ..                                                 ...
# 98   Sanaa, Yemen (CNN)As the transport plane comes...
# 99   (CNN)A former U.S. Army enlistee who posted on...
# 100  Chelsea took a commanding 3-1 lead back to wes...
# 101  Alejandro Valverde successfully defended his F...
# 102  Patrick Vieira has the backing of Manchester C...
#
#                                                Summary  \
# 0     (cnn) james best, best known for his portraya...
# 1     (cnn) the attorney for a suburban new york ca...
# 2     obama took part in a roundtable discussion on...
# 3     moscow (cnn) a russian tv video rating it mat...
# 4     republican florida republican presidential he...
# ..                                                 ...
# 98    (cnn) to sanaa airport, the deep scars of the...
# 99    army enlistee who about "" was charged with t...
# 100   chelsea took a commanding 3-1 lead west in ma...
# 101   alejandro valverde defended his wallonne titl...
# 102   manchester city manuel pellegrini's future at...
#
#                                             highlights  \
# 0    James Best, who played the sheriff on "The Duk...
# 1    A lawyer for Dr. Anthony Moschetto says the ch...
# 2    "No challenge poses more of a public threat th...
# 3    Presidential hopeful's video, featuring gay co...
# 4    Raul Reyes: In seeking Latino vote, Marco Rubi...
# ..                                                 ...
# 98   Almost 16 million people in Yemen are in need ...
# 99   Alexander Blair, 28, of Topeka accused of know...
# 100  Chelsea forward Tammy Abraham nets first-half ...
# 101  Alejandro Valverde won ahead of Julian Alaphil...
# 102  Manuel Pellegrini won the Premier League and C...
#
#                                                  noisy  \
# 0    james best, who played the sheriff on "the duk...
# 1    a lawyer for dr. anthony moschetto did not did...
# 2    "no challenge did not pose more of a public th...
# 3    presidential hopeful's video, featuring gay co...
# 4    raul reyes: in seeking latino vote, marco rubi...
# ..                                                 ...
# 98   almost 16 million people in yemen did not be i...
# 99   john t. booker jr., 20, of topeka accused of k...
# 100  chelsea forward dominic solanke nets first-hal...
# 101  alejandro valverde won ahead of julian alaphil...
# 102  manuel pellegrini won the premier league and c...
#
#                                           Pronoun_swap  \
# 0    james best, who played an sheriff on "the duke...
# 1    the lawyer for dr. anthony moschetto says an c...
# 2    "no challenge poses more of the public threat ...
# 3    presidential hopeful's video, featuring gay co...
# 4    raul reyes: in seeking latino vote, marco rubi...
# ..                                                 ...
# 98   almost 16 million people in yemen are in need ...
# 99   alexander blair, 28, of topeka accused of know...
# 100  chelsea forward tammy abraham nets first-half ...
# 101  alejandro valverde won ahead of julian alaphil...
# 102  manuel pellegrini won a premier league and cap...
#
#                                                deleted  \
# 0    james best, played the sheriff sheriff on duke...
# 1    lawyer for anthony says the charges are basele...
# 2    "no poses more of public threat than climate t...
# 3    presidential video, featuring gay gay couple, ...
# 4    raul in in seeking vote, marco rubio his own e...
# ..                                                 ...
# 98   almost 16 million people in yemen are are in n...
# 99   alexander blair, of accused of knowing about b...
# 100  chelsea forward tammy abraham abraham first-ha...
# 101  valverde won ahead ahead of julian and and mic...
# 102  manuel pellegrini won the the league and capit...
#
#                                            Predictions
# 0    "dukes of hazzard" star james best dies at 91....
# 1    anthony moschetto, 54, pleaded not guilty to c...
# 2    obama says climate change is a public health i...
# 3    a russian tv channel says there are no precede...
# 4    ruben navarrette: rubio is a newcomer to the p...
# ..                                                 ...
# 98   a u.n. mission to yemen is a rare opportunity ...
# 99   john booker abdullah, a confidential informant...
# 100  chelsea took a commanding 3-1 lead at academy ...
# 101  alejandro valverde defended his wallonne title...
# 102  manchester city have axed summer signing summe...
#
# [103 rows x 7 columns]

# %%
# save the predictions to an excel or csv.
df.to_excel("../DATA/T5_Predictions_test_BottleSum_1-340.xlsx", index=False)

# %%
import pandas as pd
df = pd.read_excel("../DATA/BART_Validation_Merged_corrupted.xlsx")

# %%
df
# Out:
#                                             highlights  \
# 0    Accident happens in Santa Ynez, California, ne...
# 1    Sigma Alpha Epsilon is being tossed out by the...
# 2    Religion professor Candida Moss appears in eac...
# 3    Two police officers were shot Wednesday in Fer...
# 4    Clinton Foundation has taken money from foreig...
# ..                                                 ...
# 995  Former Hugh Hefner companion Holly Madison has...
# 996  Sturt Manning: Video shows ISIS destroying app...
# 997  Fred Craddock revolutionized art of preaching ...
# 998  The man known as Africa often helped employees...
# 999  South African swimmer stunned Michael Phelps a...
#
#                                    distilbart-cnn-12-6  \
# 0     Singer-songwriter David Crosby hit a jogger w...
# 1     Video shows party-bound Sigma Alpha Epsilon m...
# 2     Candida Moss was an adviser on the "True Cros...
# 3     In three-quarters of all U.S. cities with pop...
# 4     The Clinton Foundation admitted last month th...
# ..                                                 ...
# 995   Holly Madison's memoir, "Down the Rabbit Hole...
# 996   ISIS has been busy trying to damage the famed...
# 997   The Rev. Fred Craddock redefined the art of p...
# 998   Los Angeles police shot and killed a homeless...
# 999   Chad le Clos beat Michael Phelps in the 200 m...
#
#                                            id  \
# 0    0044e296ecfe3ba57a351ad2a36d034491e878ce
# 1    00716be72be8cf48cc23ac3b4b8924e569628be2
# 2    00ac882e1a7f4862fa9f1e863b738966625f554d
# 3    00c45eb98a06f9218170edf5767617cc20991840
# 4    00dc77ce6c1d10bf1160829109b4f7d2a450823b
# ..                                        ...
# 995  d468092a6d909f36d26f98bcc9f14f28f8074e4e
# 996  d4cbc2386a97964145c7e6acb8fe18e16c12d5d7
# 997  d4e931e515096bd5350290b55738ccbad83c11cb
# 998  d532c558cec4abfa5ae40ac56c5db5aa51cb6363
# 999  d5c33d72b3f93661cf34192d00285ac32defc787
#
#                                                article  \
# 0    (CNN)Singer-songwriter David Crosby hit a jogg...
# 1    (CNN)Sigma Alpha Epsilon is under fire for a v...
# 2    (CNN)I'm Candida Moss and I am professor of Ne...
# 3    (CNN)Ferguson is crumbling. The cowardly and r...
# 4    Coral Gables, Florida (CNN)Former President Bi...
# ..                                                 ...
# 995  (CNN)Hugh Hefner's Playboy Mansion was a gilde...
# 996  (CNN)Confucius said: "Study the past if you wo...
# 997  (CNN)The Rev. Fred Craddock, the pulpit giant ...
# 998  Los Angeles (CNN)No one knew him by his real n...
# 999  (CNN)It was always going to take an extraordin...
#
#                                                  noisy  \
# 0    accident happens in california, santa ynez, ne...
# 1    sigma alpha epsilon is being tossed out by yal...
# 2    religion professor candida moss did not appear...
# 3    two police officers were shot wednesday in fer...
# 4    bill clinton foundation has taken money from f...
# ..                                                 ...
# 995  former hugh hefner companion madison has a mem...
# 996  sturt manning: video did not show did not bedi...
# 997  fred craddock did not revolutionize art of pre...
# 998  the man known as africa often did not help emp...
# 999  south african swi22-year-older stunned bert at...
#
#                                       Pronoun_replaced  \
# 0    accident happens in santa ynez, california, ne...
# 1    sigma alpha epsilon is being tossed out by a u...
# 2    religion professor candida moss appears in eac...
# 3    two police officers were shot wednesday in fer...
# 4    clinton foundation has taken money from foreig...
# ..                                                 ...
# 995  former hugh hefner companion holly madison has...
# 996  sturt manning: video shows isis destroying app...
# 997  fred craddock revolutionized art of preaching ...
# 998  a man known as africa often helped employees a...
# 999  south african swimmer stunned michael phelps a...
#
#                                    deleted_added_noise
# 0    accident happens happens in santa ynez, ynez, ...
# 1    sigma alpha is being tossed out by the univers...
# 2    religion professor candida candida moss appear...
# 3    two police officers were shot wednesday in fer...
# 4    clinton clinton foundation has taken money fro...
# ..                                                 ...
# 995  former hugh hefner companion holly madison a m...
# 996  manning: video shows isis destroying destroyin...
# 997  fred craddock revolutionized art preaching . ....
# 998  man known africa often employees employees at ...
# 999  south swimmer stunned michael michael phelps a...
#
# [1000 rows x 7 columns]
